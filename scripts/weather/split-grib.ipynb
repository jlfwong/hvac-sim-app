# %%
import numpy as np
import pygrib

# %%
path = "./data/all-canada-2023.grib"

all_canada_2023_grbs = pygrib.open(path)

# %%
all_canada_2024_01_01_grbs = pygrib.open("./data/all-canada-2024-01-01.grib")

# %%
all_canada_2023_grbs.seek(0)
grb = all_canada_2023_grbs.read(1)[0]

grb.values.shape
lats, lons = grb.latlons()

(np.min(lats), np.max(lats), np.min(lons), np.max(lons))
# Out:
# (41.0, 58.0, -137.0, 308.0)

# %%
ca_postal_codes = json.loads(open("./ca-postal-codes.json", "r").read())

def get_lat_lon(postal_code):
    info = ca_postal_codes[postal_code[:3]]
    return info["lat"], info["lng"]

get_lat_lon("K2A")
# Out:
# (45.3805, -75.7636)

# %%
import math


def relative_humidity(drybulb_temp_kelvin, dewpoint_temp_kelvin):
  # August-Roche-Magnus formula
  #
  # https://bmcnoldy.earth.miami.edu/Humidity.html
  # https://en.wikipedia.org/wiki/Clausius%E2%80%93Clapeyron_relation#Meteorology_and_climatology
  # 100*(EXP((17.625*TD)/(243.04+TD))/EXP((17.625*T)/(243.04+T)))
  # (Temperatures from this formula are in celcius)
  t = drybulb_temp_kelvin - 273.15
  td = dewpoint_temp_kelvin - 273.15
  return 100 * math.exp((17.625 * td) / (243.04 + td)) / math.exp((17.625 * t) / (243.04 + t))

print(relative_humidity(273.15 + (90 - 32) / 1.8, 273.15 + (63 - 32) / 1.8))
# Out:
# 40.783503702475876

# %%
import requests

def get_elevation(lat, lon):
    url = f"https://api.open-elevation.com/api/v1/lookup?locations={lat},{lon}"
    response = requests.get(url)
    data = response.json()
    elevation = data["results"][0]["elevation"]
    return elevation

elevation = get_elevation(lat, lon)  # m

# %%
def get_timezone(lat, lon):
    response = requests.get(f"http://timezonefinder.michelfe.it/api/0_{lon}_{lat}")
    location = response.json()
    timezone_str = location["tz_name"]
    return timezone_str

get_timezone(*get_lat_lon("K2A"))
# Out:
# 'America/Toronto'

# %%
# %load_ext pyinstrument
# Out:
# The pyinstrument extension is already loaded. To reload it, use:
#   %reload_ext pyinstrument

# %%
all_postal_codes = list(json.loads(open("ca-postal-codes.json").read()).keys())
len(all_postal_codes)
# Out:
# 1651

# %%
# %%pyinstrument
#
# def get_idx_for_lat_lon(lat, lon):
#     # Find the grid point with closest lat/lon
#     abslat = np.abs(lats-lat)
#     abslon = np.abs(lons-lon)
#     c = np.sqrt(np.add(np.square(abslat), np.square(abslon)))
#     idx = np.argmin(c)
#     return idx
#
#
# # Took 2m 9.7s
# postal_codes = ["K2A", "V5K", "H3H", "R3T", "T6G"]
#
# # Took 7m 58.8s
# # postal_codes = all_postal_codes[:20]
#
# # Roughly 24s/postal
#
# lat_lons = [get_lat_lon(code) for code in postal_codes]
# idx = [get_idx_for_lat_lon(lat, lon) for (lat, lon) in lat_lons]
#
# era5_data = {}
#
# # We index all of the data for every postal code up-front because we want to
# # avoid doing multiple scans of the 2GB file
# for grbs in [all_canada_2023_grbs, all_canada_2024_01_01_grbs]:
#     grbs.seek(0)
#     for grb in grbs.read():
#         year = str(grb.dataDate)[:4]
#         month = str(grb.dataDate)[4:6]
#         day = str(grb.dataDate)[6:]
#
#         time = '{:04d}'.format(grb.dataTime)
#         hour = time[:2]
#         minute = time[2:]
#
#         dt = '{}-{}-{}T{}:{}:00+00:00'.format(year, month, day, hour, minute)
#         for i, postal_code in enumerate(postal_codes):
#             era5_data.setdefault(postal_code, {}).setdefault(dt, {})[grb.name] = grb.values.flat[idx[i]]
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 10:47:04  Samples:  68684
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 135.909   CPU time: 135.770
# /   _/                      v4.6.2
#
# Program: /Users/jlfwong/code/hvac-math/scripts/weather/.venv/lib/python3.8/site-packages/ipykernel_launcher.py -f /Users/jlfwong/Library/Jupyter/runtime/kernel-b272d40e-e63c-4d21-a148-165bb30ecde6.json
#
# 135.909 <module>  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/2264968057.py:2
# |- 134.164 [self]  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/2264968057.py
# `- 1.474 count_nonzero  <__array_function__ internals>:177

# %%
list(era5_data['K2A'].keys())[-1]
# Out:
# '2024-01-01T23:00:00+00:00'

# %%
# %%pyinstrument
# wind_u_key = '10 metre U wind component'
# wind_v_key = '10 metre V wind component'
# dewpoint_temp_key = '2 metre dewpoint temperature'
# temp_key = '2 metre temperature'
# cloud_cover_key = 'Total cloud cover'
#
# timezones = [get_timezone(lat, lon) for (lat, lon) in lat_lons]
# elevations = [get_elevation(lat, lon) for (lat, lon) in lat_lons]
#
# # With 5 postal codes, this took 1m 11.0s
# #
# # Roughly 14s/postal
# #
# # Total with above: 38s/postal
# #
# # End result: 1651 postal codes * 38s/postal = ~17 hours
# #
# # Worth doing this as the last step after iterating with a small subset of postal codes
#
# results_by_postal_code = {}
# for i, postal_code in enumerate(postal_codes):
#     results_by_postal_code[postal_code] = {
#         "postalCode": postal_code,
#         "timezoneName": timezones[i],
#         "elevationMeters": elevations[i],
#     }
#     results = results_by_postal_code[postal_code]["weather"] = []
#
#     for dt, vs in era5_data[postal_code].items():
#         dt_obj = datetime.fromisoformat(dt)
#
#         solar_altitude = pysolar.solar.get_altitude(lat, lon, dt_obj, elevations[i])
#         solar_radiation = pysolar.radiation.get_radiation_direct(dt_obj, solar_altitude) if solar_altitude > 0 else 0
#
#         temp = vs[temp_key]
#         dewpoint_temp = vs[dewpoint_temp_key]
#         rh = relative_humidity(temp, dewpoint_temp)
#
#         wind_u = vs[wind_u_key]
#         wind_v = vs[wind_v_key]
#         wind_speed_10m = math.sqrt(wind_u * wind_u + wind_v * wind_v)
#         wind_speed_2m = wind_speed_10m * wind_speed_10m_to_2m_ratio
#
#         cloud_cover = vs[cloud_cover_key]
#
#         row = {
#             "datetime": dt_obj.isoformat(),
#             "outsideAirTempF": float("{:.1f}".format((temp - 273.15) * 1.8 + 32)),
#             "relativeHumidityPercent": float("{:.1f}".format(rh)),
#             "windSpeedMph": float("{:.1f}".format(wind_speed_2m * 2.237)),
#             "cloudCoverPercent": float("{:.1f}".format(cloud_cover * 100.0)),
#             "solarIrradiance": {
#                 "altitudeDegrees": float("{:.1f}".format(solar_altitude)),
#                 "wattsPerSquareMeter": float("{:.1f}".format(solar_radiation))
#             }
#         }
#         results.append(row)
#
# results_by_postal_code
# Out:
# {'K2A': {'postalCode': 'K2A',
#   'timezoneName': 'America/Toronto',
#   'elevationMeters': 73.0,
#   'weather': [{'datetime': '2023-01-01T00:00:00+00:00',
#     'outsideAirTempF': 37.1,
#     'relativeHumidityPercent': 99.3,
#     'windSpeedMph': 1.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 2.5, 'wattsPerSquareMeter': 49.8}},
#    {'datetime': '2023-01-01T01:00:00+00:00',
#     'outsideAirTempF': 37.3,
#     'relativeHumidityPercent': 99.4,
#     'windSpeedMph': 2.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -5.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T02:00:00+00:00',
#     'outsideAirTempF': 37.4,
#     'relativeHumidityPercent': 99.2,
#     'windSpeedMph': 3.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -14.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T03:00:00+00:00',
#     'outsideAirTempF': 37.3,
#     'relativeHumidityPercent': 99.2,
#     'windSpeedMph': 4.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -24.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T04:00:00+00:00',
#     'outsideAirTempF': 37.6,
#     'relativeHumidityPercent': 99.0,
#     'windSpeedMph': 4.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -34.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T05:00:00+00:00',
#     'outsideAirTempF': 37.8,
#     'relativeHumidityPercent': 98.4,
#     'windSpeedMph': 5.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -43.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T06:00:00+00:00',
#     'outsideAirTempF': 37.8,
#     'relativeHumidityPercent': 97.8,
#     'windSpeedMph': 5.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -52.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T07:00:00+00:00',
#     'outsideAirTempF': 37.3,
#     'relativeHumidityPercent': 97.2,
#     'windSpeedMph': 4.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -59.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T08:00:00+00:00',
#     'outsideAirTempF': 36.8,
#     'relativeHumidityPercent': 96.7,
#     'windSpeedMph': 6.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -63.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T09:00:00+00:00',
#     'outsideAirTempF': 36.4,
#     'relativeHumidityPercent': 96.6,
#     'windSpeedMph': 6.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -62.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T10:00:00+00:00',
#     'outsideAirTempF': 36.2,
#     'relativeHumidityPercent': 94.1,
#     'windSpeedMph': 6.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -56.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T11:00:00+00:00',
#     'outsideAirTempF': 36.0,
#     'relativeHumidityPercent': 94.5,
#     'windSpeedMph': 5.9,
#     'cloudCoverPercent': 95.8,
#     'solarIrradiance': {'altitudeDegrees': -48.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T12:00:00+00:00',
#     'outsideAirTempF': 35.9,
#     'relativeHumidityPercent': 93.8,
#     'windSpeedMph': 5.8,
#     'cloudCoverPercent': 95.2,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T13:00:00+00:00',
#     'outsideAirTempF': 35.8,
#     'relativeHumidityPercent': 93.5,
#     'windSpeedMph': 5.8,
#     'cloudCoverPercent': 95.2,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T14:00:00+00:00',
#     'outsideAirTempF': 35.9,
#     'relativeHumidityPercent': 92.0,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': -19.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T15:00:00+00:00',
#     'outsideAirTempF': 36.2,
#     'relativeHumidityPercent': 90.6,
#     'windSpeedMph': 4.4,
#     'cloudCoverPercent': 90.0,
#     'solarIrradiance': {'altitudeDegrees': -10.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T16:00:00+00:00',
#     'outsideAirTempF': 36.5,
#     'relativeHumidityPercent': 86.9,
#     'windSpeedMph': 4.8,
#     'cloudCoverPercent': 98.0,
#     'solarIrradiance': {'altitudeDegrees': -1.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-01T17:00:00+00:00',
#     'outsideAirTempF': 36.5,
#     'relativeHumidityPercent': 85.3,
#     'windSpeedMph': 5.0,
#     'cloudCoverPercent': 98.2,
#     'solarIrradiance': {'altitudeDegrees': 5.8, 'wattsPerSquareMeter': 308.7}},
#    {'datetime': '2023-01-01T18:00:00+00:00',
#     'outsideAirTempF': 36.8,
#     'relativeHumidityPercent': 82.9,
#     'windSpeedMph': 5.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 11.7,
#      'wattsPerSquareMeter': 622.4}},
#    {'datetime': '2023-01-01T19:00:00+00:00',
#     'outsideAirTempF': 36.6,
#     'relativeHumidityPercent': 80.5,
#     'windSpeedMph': 4.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 15.8,
#      'wattsPerSquareMeter': 741.5}},
#    {'datetime': '2023-01-01T20:00:00+00:00',
#     'outsideAirTempF': 35.9,
#     'relativeHumidityPercent': 82.9,
#     'windSpeedMph': 3.4,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': 17.7,
#      'wattsPerSquareMeter': 781.5}},
#    {'datetime': '2023-01-01T21:00:00+00:00',
#     'outsideAirTempF': 35.3,
#     'relativeHumidityPercent': 84.7,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 17.2,
#      'wattsPerSquareMeter': 770.2}},
#    {'datetime': '2023-01-01T22:00:00+00:00',
#     'outsideAirTempF': 34.0,
#     'relativeHumidityPercent': 88.2,
#     'windSpeedMph': 3.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 14.2,
#      'wattsPerSquareMeter': 700.6}},
#    {'datetime': '2023-01-01T23:00:00+00:00',
#     'outsideAirTempF': 33.7,
#     'relativeHumidityPercent': 89.6,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 9.2, 'wattsPerSquareMeter': 516.9}},
#    {'datetime': '2023-01-02T00:00:00+00:00',
#     'outsideAirTempF': 33.6,
#     'relativeHumidityPercent': 90.6,
#     'windSpeedMph': 1.8,
#     'cloudCoverPercent': 86.2,
#     'solarIrradiance': {'altitudeDegrees': 2.6, 'wattsPerSquareMeter': 57.9}},
#    {'datetime': '2023-01-02T01:00:00+00:00',
#     'outsideAirTempF': 33.2,
#     'relativeHumidityPercent': 91.4,
#     'windSpeedMph': 1.8,
#     'cloudCoverPercent': 82.5,
#     'solarIrradiance': {'altitudeDegrees': -5.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T02:00:00+00:00',
#     'outsideAirTempF': 33.1,
#     'relativeHumidityPercent': 92.8,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 96.6,
#     'solarIrradiance': {'altitudeDegrees': -14.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T03:00:00+00:00',
#     'outsideAirTempF': 31.8,
#     'relativeHumidityPercent': 94.0,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 69.9,
#     'solarIrradiance': {'altitudeDegrees': -24.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T04:00:00+00:00',
#     'outsideAirTempF': 30.9,
#     'relativeHumidityPercent': 94.8,
#     'windSpeedMph': 2.0,
#     'cloudCoverPercent': 38.4,
#     'solarIrradiance': {'altitudeDegrees': -33.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T05:00:00+00:00',
#     'outsideAirTempF': 31.6,
#     'relativeHumidityPercent': 95.2,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 60.6,
#     'solarIrradiance': {'altitudeDegrees': -43.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T06:00:00+00:00',
#     'outsideAirTempF': 31.7,
#     'relativeHumidityPercent': 95.1,
#     'windSpeedMph': 2.7,
#     'cloudCoverPercent': 86.6,
#     'solarIrradiance': {'altitudeDegrees': -52.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T07:00:00+00:00',
#     'outsideAirTempF': 32.0,
#     'relativeHumidityPercent': 95.0,
#     'windSpeedMph': 2.6,
#     'cloudCoverPercent': 96.4,
#     'solarIrradiance': {'altitudeDegrees': -59.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T08:00:00+00:00',
#     'outsideAirTempF': 32.3,
#     'relativeHumidityPercent': 95.5,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': -63.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T09:00:00+00:00',
#     'outsideAirTempF': 32.6,
#     'relativeHumidityPercent': 95.9,
#     'windSpeedMph': 2.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -62.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T10:00:00+00:00',
#     'outsideAirTempF': 32.2,
#     'relativeHumidityPercent': 96.0,
#     'windSpeedMph': 3.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -56.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T11:00:00+00:00',
#     'outsideAirTempF': 32.3,
#     'relativeHumidityPercent': 95.8,
#     'windSpeedMph': 3.6,
#     'cloudCoverPercent': 97.4,
#     'solarIrradiance': {'altitudeDegrees': -48.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T12:00:00+00:00',
#     'outsideAirTempF': 33.2,
#     'relativeHumidityPercent': 95.5,
#     'windSpeedMph': 4.3,
#     'cloudCoverPercent': 80.5,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T13:00:00+00:00',
#     'outsideAirTempF': 33.9,
#     'relativeHumidityPercent': 94.0,
#     'windSpeedMph': 4.7,
#     'cloudCoverPercent': 89.6,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T14:00:00+00:00',
#     'outsideAirTempF': 34.8,
#     'relativeHumidityPercent': 92.3,
#     'windSpeedMph': 5.3,
#     'cloudCoverPercent': 98.8,
#     'solarIrradiance': {'altitudeDegrees': -19.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T15:00:00+00:00',
#     'outsideAirTempF': 36.5,
#     'relativeHumidityPercent': 89.0,
#     'windSpeedMph': 5.5,
#     'cloudCoverPercent': 98.6,
#     'solarIrradiance': {'altitudeDegrees': -10.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T16:00:00+00:00',
#     'outsideAirTempF': 37.5,
#     'relativeHumidityPercent': 86.2,
#     'windSpeedMph': 6.3,
#     'cloudCoverPercent': 90.4,
#     'solarIrradiance': {'altitudeDegrees': -1.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-02T17:00:00+00:00',
#     'outsideAirTempF': 38.2,
#     'relativeHumidityPercent': 79.3,
#     'windSpeedMph': 6.6,
#     'cloudCoverPercent': 34.4,
#     'solarIrradiance': {'altitudeDegrees': 5.8, 'wattsPerSquareMeter': 310.6}},
#    {'datetime': '2023-01-02T18:00:00+00:00',
#     'outsideAirTempF': 38.8,
#     'relativeHumidityPercent': 73.9,
#     'windSpeedMph': 6.8,
#     'cloudCoverPercent': 39.3,
#     'solarIrradiance': {'altitudeDegrees': 11.8,
#      'wattsPerSquareMeter': 624.1}},
#    {'datetime': '2023-01-02T19:00:00+00:00',
#     'outsideAirTempF': 39.1,
#     'relativeHumidityPercent': 71.1,
#     'windSpeedMph': 6.0,
#     'cloudCoverPercent': 46.6,
#     'solarIrradiance': {'altitudeDegrees': 15.9,
#      'wattsPerSquareMeter': 743.1}},
#    {'datetime': '2023-01-02T20:00:00+00:00',
#     'outsideAirTempF': 38.4,
#     'relativeHumidityPercent': 73.7,
#     'windSpeedMph': 4.2,
#     'cloudCoverPercent': 33.3,
#     'solarIrradiance': {'altitudeDegrees': 17.8,
#      'wattsPerSquareMeter': 783.3}},
#    {'datetime': '2023-01-02T21:00:00+00:00',
#     'outsideAirTempF': 35.5,
#     'relativeHumidityPercent': 80.2,
#     'windSpeedMph': 3.7,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 17.3,
#      'wattsPerSquareMeter': 772.5}},
#    {'datetime': '2023-01-02T22:00:00+00:00',
#     'outsideAirTempF': 35.0,
#     'relativeHumidityPercent': 82.4,
#     'windSpeedMph': 3.6,
#     'cloudCoverPercent': 84.3,
#     'solarIrradiance': {'altitudeDegrees': 14.3,
#      'wattsPerSquareMeter': 703.9}},
#    {'datetime': '2023-01-02T23:00:00+00:00',
#     'outsideAirTempF': 34.5,
#     'relativeHumidityPercent': 84.5,
#     'windSpeedMph': 3.5,
#     'cloudCoverPercent': 70.8,
#     'solarIrradiance': {'altitudeDegrees': 9.3, 'wattsPerSquareMeter': 523.2}},
#    {'datetime': '2023-01-03T00:00:00+00:00',
#     'outsideAirTempF': 34.4,
#     'relativeHumidityPercent': 86.3,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 71.5,
#     'solarIrradiance': {'altitudeDegrees': 2.7, 'wattsPerSquareMeter': 66.8}},
#    {'datetime': '2023-01-03T01:00:00+00:00',
#     'outsideAirTempF': 34.3,
#     'relativeHumidityPercent': 87.4,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 80.9,
#     'solarIrradiance': {'altitudeDegrees': -5.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T02:00:00+00:00',
#     'outsideAirTempF': 34.5,
#     'relativeHumidityPercent': 88.2,
#     'windSpeedMph': 2.5,
#     'cloudCoverPercent': 90.6,
#     'solarIrradiance': {'altitudeDegrees': -14.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T03:00:00+00:00',
#     'outsideAirTempF': 33.3,
#     'relativeHumidityPercent': 89.8,
#     'windSpeedMph': 2.6,
#     'cloudCoverPercent': 95.6,
#     'solarIrradiance': {'altitudeDegrees': -24.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T04:00:00+00:00',
#     'outsideAirTempF': 32.7,
#     'relativeHumidityPercent': 91.3,
#     'windSpeedMph': 2.0,
#     'cloudCoverPercent': 90.4,
#     'solarIrradiance': {'altitudeDegrees': -33.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T05:00:00+00:00',
#     'outsideAirTempF': 32.8,
#     'relativeHumidityPercent': 92.7,
#     'windSpeedMph': 2.1,
#     'cloudCoverPercent': 98.4,
#     'solarIrradiance': {'altitudeDegrees': -43.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T06:00:00+00:00',
#     'outsideAirTempF': 32.5,
#     'relativeHumidityPercent': 92.7,
#     'windSpeedMph': 2.7,
#     'cloudCoverPercent': 99.2,
#     'solarIrradiance': {'altitudeDegrees': -52.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T07:00:00+00:00',
#     'outsideAirTempF': 32.4,
#     'relativeHumidityPercent': 94.0,
#     'windSpeedMph': 2.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -59.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T08:00:00+00:00',
#     'outsideAirTempF': 31.1,
#     'relativeHumidityPercent': 94.3,
#     'windSpeedMph': 2.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -63.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T09:00:00+00:00',
#     'outsideAirTempF': 29.4,
#     'relativeHumidityPercent': 95.5,
#     'windSpeedMph': 2.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -62.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T10:00:00+00:00',
#     'outsideAirTempF': 30.2,
#     'relativeHumidityPercent': 96.1,
#     'windSpeedMph': 2.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -56.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T11:00:00+00:00',
#     'outsideAirTempF': 30.6,
#     'relativeHumidityPercent': 95.8,
#     'windSpeedMph': 2.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -48.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T12:00:00+00:00',
#     'outsideAirTempF': 30.4,
#     'relativeHumidityPercent': 97.2,
#     'windSpeedMph': 1.7,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T13:00:00+00:00',
#     'outsideAirTempF': 29.7,
#     'relativeHumidityPercent': 98.0,
#     'windSpeedMph': 1.9,
#     'cloudCoverPercent': 98.6,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T14:00:00+00:00',
#     'outsideAirTempF': 30.6,
#     'relativeHumidityPercent': 96.4,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 95.8,
#     'solarIrradiance': {'altitudeDegrees': -19.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T15:00:00+00:00',
#     'outsideAirTempF': 32.2,
#     'relativeHumidityPercent': 92.7,
#     'windSpeedMph': 2.5,
#     'cloudCoverPercent': 99.6,
#     'solarIrradiance': {'altitudeDegrees': -10.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T16:00:00+00:00',
#     'outsideAirTempF': 33.5,
#     'relativeHumidityPercent': 88.7,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -1.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-03T17:00:00+00:00',
#     'outsideAirTempF': 34.4,
#     'relativeHumidityPercent': 84.8,
#     'windSpeedMph': 2.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 5.8, 'wattsPerSquareMeter': 313.0}},
#    {'datetime': '2023-01-03T18:00:00+00:00',
#     'outsideAirTempF': 35.2,
#     'relativeHumidityPercent': 82.5,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 11.8,
#      'wattsPerSquareMeter': 626.0}},
#    {'datetime': '2023-01-03T19:00:00+00:00',
#     'outsideAirTempF': 36.1,
#     'relativeHumidityPercent': 78.1,
#     'windSpeedMph': 2.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 16.0,
#      'wattsPerSquareMeter': 744.9}},
#    {'datetime': '2023-01-03T20:00:00+00:00',
#     'outsideAirTempF': 36.1,
#     'relativeHumidityPercent': 78.2,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 17.9,
#      'wattsPerSquareMeter': 785.2}},
#    {'datetime': '2023-01-03T21:00:00+00:00',
#     'outsideAirTempF': 35.8,
#     'relativeHumidityPercent': 80.8,
#     'windSpeedMph': 3.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 17.4,
#      'wattsPerSquareMeter': 774.9}},
#    {'datetime': '2023-01-03T22:00:00+00:00',
#     'outsideAirTempF': 34.4,
#     'relativeHumidityPercent': 82.1,
#     'windSpeedMph': 3.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 14.5,
#      'wattsPerSquareMeter': 707.4}},
#    {'datetime': '2023-01-03T23:00:00+00:00',
#     'outsideAirTempF': 33.8,
#     'relativeHumidityPercent': 83.6,
#     'windSpeedMph': 3.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 9.5, 'wattsPerSquareMeter': 529.7}},
#    {'datetime': '2023-01-04T00:00:00+00:00',
#     'outsideAirTempF': 33.9,
#     'relativeHumidityPercent': 84.8,
#     'windSpeedMph': 4.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 2.9, 'wattsPerSquareMeter': 76.4}},
#    {'datetime': '2023-01-04T01:00:00+00:00',
#     'outsideAirTempF': 33.8,
#     'relativeHumidityPercent': 85.4,
#     'windSpeedMph': 4.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -5.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T02:00:00+00:00',
#     'outsideAirTempF': 33.6,
#     'relativeHumidityPercent': 85.9,
#     'windSpeedMph': 4.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -14.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T03:00:00+00:00',
#     'outsideAirTempF': 33.7,
#     'relativeHumidityPercent': 87.0,
#     'windSpeedMph': 4.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -23.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T04:00:00+00:00',
#     'outsideAirTempF': 34.1,
#     'relativeHumidityPercent': 86.7,
#     'windSpeedMph': 4.5,
#     'cloudCoverPercent': 99.0,
#     'solarIrradiance': {'altitudeDegrees': -33.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T05:00:00+00:00',
#     'outsideAirTempF': 33.8,
#     'relativeHumidityPercent': 88.1,
#     'windSpeedMph': 4.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -43.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T06:00:00+00:00',
#     'outsideAirTempF': 33.9,
#     'relativeHumidityPercent': 88.7,
#     'windSpeedMph': 4.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -52.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T07:00:00+00:00',
#     'outsideAirTempF': 33.9,
#     'relativeHumidityPercent': 88.9,
#     'windSpeedMph': 4.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -59.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T08:00:00+00:00',
#     'outsideAirTempF': 34.1,
#     'relativeHumidityPercent': 89.5,
#     'windSpeedMph': 3.4,
#     'cloudCoverPercent': 94.1,
#     'solarIrradiance': {'altitudeDegrees': -63.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T09:00:00+00:00',
#     'outsideAirTempF': 34.2,
#     'relativeHumidityPercent': 90.7,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -62.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T10:00:00+00:00',
#     'outsideAirTempF': 33.6,
#     'relativeHumidityPercent': 91.6,
#     'windSpeedMph': 4.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -56.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T11:00:00+00:00',
#     'outsideAirTempF': 33.7,
#     'relativeHumidityPercent': 91.1,
#     'windSpeedMph': 3.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -48.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T12:00:00+00:00',
#     'outsideAirTempF': 33.6,
#     'relativeHumidityPercent': 91.4,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T13:00:00+00:00',
#     'outsideAirTempF': 33.5,
#     'relativeHumidityPercent': 91.9,
#     'windSpeedMph': 3.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T14:00:00+00:00',
#     'outsideAirTempF': 34.0,
#     'relativeHumidityPercent': 90.1,
#     'windSpeedMph': 3.7,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -19.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T15:00:00+00:00',
#     'outsideAirTempF': 35.0,
#     'relativeHumidityPercent': 86.4,
#     'windSpeedMph': 3.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -10.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T16:00:00+00:00',
#     'outsideAirTempF': 35.5,
#     'relativeHumidityPercent': 83.9,
#     'windSpeedMph': 4.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -1.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-04T17:00:00+00:00',
#     'outsideAirTempF': 36.0,
#     'relativeHumidityPercent': 81.9,
#     'windSpeedMph': 4.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 5.9, 'wattsPerSquareMeter': 315.9}},
#    {'datetime': '2023-01-04T18:00:00+00:00',
#     'outsideAirTempF': 36.5,
#     'relativeHumidityPercent': 79.2,
#     'windSpeedMph': 4.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 11.9,
#      'wattsPerSquareMeter': 628.2}},
#    {'datetime': '2023-01-04T19:00:00+00:00',
#     'outsideAirTempF': 36.5,
#     'relativeHumidityPercent': 78.3,
#     'windSpeedMph': 4.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 16.1,
#      'wattsPerSquareMeter': 746.8}},
#    {'datetime': '2023-01-04T20:00:00+00:00',
#     'outsideAirTempF': 36.2,
#     'relativeHumidityPercent': 79.7,
#     'windSpeedMph': 5.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 18.0,
#      'wattsPerSquareMeter': 787.2}},
#    {'datetime': '2023-01-04T21:00:00+00:00',
#     'outsideAirTempF': 35.7,
#     'relativeHumidityPercent': 81.4,
#     'windSpeedMph': 5.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 17.5,
#      'wattsPerSquareMeter': 777.3}},
#    {'datetime': '2023-01-04T22:00:00+00:00',
#     'outsideAirTempF': 34.5,
#     'relativeHumidityPercent': 87.7,
#     'windSpeedMph': 5.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 14.6,
#      'wattsPerSquareMeter': 711.0}},
#    {'datetime': '2023-01-04T23:00:00+00:00',
#     'outsideAirTempF': 34.3,
#     'relativeHumidityPercent': 88.3,
#     'windSpeedMph': 6.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 9.6, 'wattsPerSquareMeter': 536.3}},
#    {'datetime': '2023-01-05T00:00:00+00:00',
#     'outsideAirTempF': 34.2,
#     'relativeHumidityPercent': 89.9,
#     'windSpeedMph': 8.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 3.0, 'wattsPerSquareMeter': 86.9}},
#    {'datetime': '2023-01-05T01:00:00+00:00',
#     'outsideAirTempF': 33.8,
#     'relativeHumidityPercent': 89.9,
#     'windSpeedMph': 8.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -5.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T02:00:00+00:00',
#     'outsideAirTempF': 33.0,
#     'relativeHumidityPercent': 86.7,
#     'windSpeedMph': 9.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -14.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T03:00:00+00:00',
#     'outsideAirTempF': 31.4,
#     'relativeHumidityPercent': 82.9,
#     'windSpeedMph': 10.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -23.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T04:00:00+00:00',
#     'outsideAirTempF': 29.5,
#     'relativeHumidityPercent': 83.9,
#     'windSpeedMph': 9.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -33.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T05:00:00+00:00',
#     'outsideAirTempF': 28.1,
#     'relativeHumidityPercent': 85.6,
#     'windSpeedMph': 9.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -43.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T06:00:00+00:00',
#     'outsideAirTempF': 27.8,
#     'relativeHumidityPercent': 87.7,
#     'windSpeedMph': 9.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -52.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T07:00:00+00:00',
#     'outsideAirTempF': 28.0,
#     'relativeHumidityPercent': 90.4,
#     'windSpeedMph': 8.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -59.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T08:00:00+00:00',
#     'outsideAirTempF': 27.9,
#     'relativeHumidityPercent': 92.4,
#     'windSpeedMph': 6.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -63.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T09:00:00+00:00',
#     'outsideAirTempF': 27.9,
#     'relativeHumidityPercent': 93.7,
#     'windSpeedMph': 5.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -62.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T10:00:00+00:00',
#     'outsideAirTempF': 27.1,
#     'relativeHumidityPercent': 93.4,
#     'windSpeedMph': 3.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -56.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T11:00:00+00:00',
#     'outsideAirTempF': 26.7,
#     'relativeHumidityPercent': 93.9,
#     'windSpeedMph': 3.7,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -48.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T12:00:00+00:00',
#     'outsideAirTempF': 26.6,
#     'relativeHumidityPercent': 93.6,
#     'windSpeedMph': 3.5,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T13:00:00+00:00',
#     'outsideAirTempF': 26.5,
#     'relativeHumidityPercent': 93.4,
#     'windSpeedMph': 3.1,
#     'cloudCoverPercent': 98.2,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T14:00:00+00:00',
#     'outsideAirTempF': 27.1,
#     'relativeHumidityPercent': 91.1,
#     'windSpeedMph': 3.0,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': -19.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T15:00:00+00:00',
#     'outsideAirTempF': 27.7,
#     'relativeHumidityPercent': 92.3,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -10.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T16:00:00+00:00',
#     'outsideAirTempF': 27.7,
#     'relativeHumidityPercent': 92.9,
#     'windSpeedMph': 2.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -1.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-05T17:00:00+00:00',
#     'outsideAirTempF': 28.6,
#     'relativeHumidityPercent': 92.4,
#     'windSpeedMph': 1.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 5.9, 'wattsPerSquareMeter': 319.2}},
#    {'datetime': '2023-01-05T18:00:00+00:00',
#     'outsideAirTempF': 29.4,
#     'relativeHumidityPercent': 92.0,
#     'windSpeedMph': 2.2,
#     'cloudCoverPercent': 99.6,
#     'solarIrradiance': {'altitudeDegrees': 11.9,
#      'wattsPerSquareMeter': 630.5}},
#    {'datetime': '2023-01-05T19:00:00+00:00',
#     'outsideAirTempF': 29.5,
#     'relativeHumidityPercent': 93.1,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 16.1,
#      'wattsPerSquareMeter': 748.8}},
#    {'datetime': '2023-01-05T20:00:00+00:00',
#     'outsideAirTempF': 30.1,
#     'relativeHumidityPercent': 94.1,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 18.1,
#      'wattsPerSquareMeter': 789.2}},
#    {'datetime': '2023-01-05T21:00:00+00:00',
#     'outsideAirTempF': 30.0,
#     'relativeHumidityPercent': 96.9,
#     'windSpeedMph': 3.2,
#     'cloudCoverPercent': 97.6,
#     'solarIrradiance': {'altitudeDegrees': 17.6,
#      'wattsPerSquareMeter': 779.8}},
#    {'datetime': '2023-01-05T22:00:00+00:00',
#     'outsideAirTempF': 29.4,
#     'relativeHumidityPercent': 99.2,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 99.0,
#     'solarIrradiance': {'altitudeDegrees': 14.7,
#      'wattsPerSquareMeter': 714.6}},
#    {'datetime': '2023-01-05T23:00:00+00:00',
#     'outsideAirTempF': 29.8,
#     'relativeHumidityPercent': 99.6,
#     'windSpeedMph': 3.7,
#     'cloudCoverPercent': 98.2,
#     'solarIrradiance': {'altitudeDegrees': 9.7, 'wattsPerSquareMeter': 543.0}},
#    {'datetime': '2023-01-06T00:00:00+00:00',
#     'outsideAirTempF': 30.3,
#     'relativeHumidityPercent': 99.8,
#     'windSpeedMph': 4.0,
#     'cloudCoverPercent': 96.4,
#     'solarIrradiance': {'altitudeDegrees': 3.1, 'wattsPerSquareMeter': 98.1}},
#    {'datetime': '2023-01-06T01:00:00+00:00',
#     'outsideAirTempF': 30.6,
#     'relativeHumidityPercent': 99.8,
#     'windSpeedMph': 4.3,
#     'cloudCoverPercent': 92.8,
#     'solarIrradiance': {'altitudeDegrees': -5.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T02:00:00+00:00',
#     'outsideAirTempF': 30.2,
#     'relativeHumidityPercent': 99.7,
#     'windSpeedMph': 4.0,
#     'cloudCoverPercent': 91.3,
#     'solarIrradiance': {'altitudeDegrees': -14.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T03:00:00+00:00',
#     'outsideAirTempF': 29.6,
#     'relativeHumidityPercent': 99.3,
#     'windSpeedMph': 3.8,
#     'cloudCoverPercent': 85.9,
#     'solarIrradiance': {'altitudeDegrees': -23.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T04:00:00+00:00',
#     'outsideAirTempF': 29.0,
#     'relativeHumidityPercent': 99.3,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': -33.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T05:00:00+00:00',
#     'outsideAirTempF': 29.0,
#     'relativeHumidityPercent': 99.0,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 97.2,
#     'solarIrradiance': {'altitudeDegrees': -43.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T06:00:00+00:00',
#     'outsideAirTempF': 29.0,
#     'relativeHumidityPercent': 98.9,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 89.0,
#     'solarIrradiance': {'altitudeDegrees': -51.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T07:00:00+00:00',
#     'outsideAirTempF': 27.8,
#     'relativeHumidityPercent': 98.8,
#     'windSpeedMph': 3.1,
#     'cloudCoverPercent': 90.8,
#     'solarIrradiance': {'altitudeDegrees': -59.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T08:00:00+00:00',
#     'outsideAirTempF': 27.5,
#     'relativeHumidityPercent': 98.7,
#     'windSpeedMph': 2.9,
#     'cloudCoverPercent': 98.0,
#     'solarIrradiance': {'altitudeDegrees': -63.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T09:00:00+00:00',
#     'outsideAirTempF': 26.2,
#     'relativeHumidityPercent': 99.5,
#     'windSpeedMph': 2.6,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': -62.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T10:00:00+00:00',
#     'outsideAirTempF': 29.8,
#     'relativeHumidityPercent': 98.8,
#     'windSpeedMph': 2.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -56.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T11:00:00+00:00',
#     'outsideAirTempF': 30.1,
#     'relativeHumidityPercent': 98.9,
#     'windSpeedMph': 2.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -48.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T12:00:00+00:00',
#     'outsideAirTempF': 30.5,
#     'relativeHumidityPercent': 99.2,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T13:00:00+00:00',
#     'outsideAirTempF': 30.9,
#     'relativeHumidityPercent': 99.3,
#     'windSpeedMph': 2.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T14:00:00+00:00',
#     'outsideAirTempF': 31.1,
#     'relativeHumidityPercent': 98.6,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -19.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T15:00:00+00:00',
#     'outsideAirTempF': 31.8,
#     'relativeHumidityPercent': 97.2,
#     'windSpeedMph': 2.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -10.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T16:00:00+00:00',
#     'outsideAirTempF': 32.0,
#     'relativeHumidityPercent': 96.8,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -1.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-06T17:00:00+00:00',
#     'outsideAirTempF': 32.4,
#     'relativeHumidityPercent': 95.7,
#     'windSpeedMph': 3.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 6.0, 'wattsPerSquareMeter': 322.9}},
#    {'datetime': '2023-01-06T18:00:00+00:00',
#     'outsideAirTempF': 33.2,
#     'relativeHumidityPercent': 93.7,
#     'windSpeedMph': 3.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 12.0,
#      'wattsPerSquareMeter': 633.0}},
#    {'datetime': '2023-01-06T19:00:00+00:00',
#     'outsideAirTempF': 34.1,
#     'relativeHumidityPercent': 91.5,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 16.2,
#      'wattsPerSquareMeter': 750.9}},
#    {'datetime': '2023-01-06T20:00:00+00:00',
#     'outsideAirTempF': 33.6,
#     'relativeHumidityPercent': 94.8,
#     'windSpeedMph': 2.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 18.2,
#      'wattsPerSquareMeter': 791.4}},
#    {'datetime': '2023-01-06T21:00:00+00:00',
#     'outsideAirTempF': 33.2,
#     'relativeHumidityPercent': 96.3,
#     'windSpeedMph': 2.5,
#     'cloudCoverPercent': 98.2,
#     'solarIrradiance': {'altitudeDegrees': 17.7,
#      'wattsPerSquareMeter': 782.4}},
#    {'datetime': '2023-01-06T22:00:00+00:00',
#     'outsideAirTempF': 32.0,
#     'relativeHumidityPercent': 94.6,
#     'windSpeedMph': 3.1,
#     'cloudCoverPercent': 93.8,
#     'solarIrradiance': {'altitudeDegrees': 14.9,
#      'wattsPerSquareMeter': 718.3}},
#    {'datetime': '2023-01-06T23:00:00+00:00',
#     'outsideAirTempF': 32.1,
#     'relativeHumidityPercent': 94.9,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': 9.9, 'wattsPerSquareMeter': 549.8}},
#    {'datetime': '2023-01-07T00:00:00+00:00',
#     'outsideAirTempF': 32.4,
#     'relativeHumidityPercent': 95.7,
#     'windSpeedMph': 4.0,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 3.3, 'wattsPerSquareMeter': 110.0}},
#    {'datetime': '2023-01-07T01:00:00+00:00',
#     'outsideAirTempF': 32.5,
#     'relativeHumidityPercent': 95.8,
#     'windSpeedMph': 5.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -5.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T02:00:00+00:00',
#     'outsideAirTempF': 32.3,
#     'relativeHumidityPercent': 93.1,
#     'windSpeedMph': 5.9,
#     'cloudCoverPercent': 92.6,
#     'solarIrradiance': {'altitudeDegrees': -13.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T03:00:00+00:00',
#     'outsideAirTempF': 31.0,
#     'relativeHumidityPercent': 87.9,
#     'windSpeedMph': 6.2,
#     'cloudCoverPercent': 85.3,
#     'solarIrradiance': {'altitudeDegrees': -23.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T04:00:00+00:00',
#     'outsideAirTempF': 29.5,
#     'relativeHumidityPercent': 85.9,
#     'windSpeedMph': 6.2,
#     'cloudCoverPercent': 93.4,
#     'solarIrradiance': {'altitudeDegrees': -33.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T05:00:00+00:00',
#     'outsideAirTempF': 27.8,
#     'relativeHumidityPercent': 84.8,
#     'windSpeedMph': 5.8,
#     'cloudCoverPercent': 97.0,
#     'solarIrradiance': {'altitudeDegrees': -42.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T06:00:00+00:00',
#     'outsideAirTempF': 26.3,
#     'relativeHumidityPercent': 83.2,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 93.8,
#     'solarIrradiance': {'altitudeDegrees': -51.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T07:00:00+00:00',
#     'outsideAirTempF': 25.2,
#     'relativeHumidityPercent': 82.9,
#     'windSpeedMph': 5.5,
#     'cloudCoverPercent': 93.0,
#     'solarIrradiance': {'altitudeDegrees': -59.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T08:00:00+00:00',
#     'outsideAirTempF': 24.4,
#     'relativeHumidityPercent': 82.0,
#     'windSpeedMph': 5.6,
#     'cloudCoverPercent': 98.6,
#     'solarIrradiance': {'altitudeDegrees': -62.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T09:00:00+00:00',
#     'outsideAirTempF': 23.9,
#     'relativeHumidityPercent': 81.3,
#     'windSpeedMph': 5.7,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -61.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T10:00:00+00:00',
#     'outsideAirTempF': 23.3,
#     'relativeHumidityPercent': 75.5,
#     'windSpeedMph': 6.4,
#     'cloudCoverPercent': 99.4,
#     'solarIrradiance': {'altitudeDegrees': -56.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T11:00:00+00:00',
#     'outsideAirTempF': 23.1,
#     'relativeHumidityPercent': 74.5,
#     'windSpeedMph': 6.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -48.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T12:00:00+00:00',
#     'outsideAirTempF': 22.9,
#     'relativeHumidityPercent': 73.6,
#     'windSpeedMph': 6.1,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T13:00:00+00:00',
#     'outsideAirTempF': 22.3,
#     'relativeHumidityPercent': 75.4,
#     'windSpeedMph': 6.0,
#     'cloudCoverPercent': 99.0,
#     'solarIrradiance': {'altitudeDegrees': -29.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T14:00:00+00:00',
#     'outsideAirTempF': 22.3,
#     'relativeHumidityPercent': 75.4,
#     'windSpeedMph': 5.7,
#     'cloudCoverPercent': 98.8,
#     'solarIrradiance': {'altitudeDegrees': -19.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T15:00:00+00:00',
#     'outsideAirTempF': 22.8,
#     'relativeHumidityPercent': 76.8,
#     'windSpeedMph': 5.8,
#     'cloudCoverPercent': 96.2,
#     'solarIrradiance': {'altitudeDegrees': -10.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T16:00:00+00:00',
#     'outsideAirTempF': 22.9,
#     'relativeHumidityPercent': 73.4,
#     'windSpeedMph': 6.1,
#     'cloudCoverPercent': 96.0,
#     'solarIrradiance': {'altitudeDegrees': -1.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-07T17:00:00+00:00',
#     'outsideAirTempF': 22.9,
#     'relativeHumidityPercent': 70.0,
#     'windSpeedMph': 6.3,
#     'cloudCoverPercent': 60.9,
#     'solarIrradiance': {'altitudeDegrees': 6.0, 'wattsPerSquareMeter': 327.1}},
#    {'datetime': '2023-01-07T18:00:00+00:00',
#     'outsideAirTempF': 22.9,
#     'relativeHumidityPercent': 68.0,
#     'windSpeedMph': 6.6,
#     'cloudCoverPercent': 10.2,
#     'solarIrradiance': {'altitudeDegrees': 12.1,
#      'wattsPerSquareMeter': 635.7}},
#    {'datetime': '2023-01-07T19:00:00+00:00',
#     'outsideAirTempF': 22.2,
#     'relativeHumidityPercent': 67.1,
#     'windSpeedMph': 6.9,
#     'cloudCoverPercent': 2.6,
#     'solarIrradiance': {'altitudeDegrees': 16.3,
#      'wattsPerSquareMeter': 753.1}},
#    {'datetime': '2023-01-07T20:00:00+00:00',
#     'outsideAirTempF': 21.8,
#     'relativeHumidityPercent': 67.5,
#     'windSpeedMph': 7.0,
#     'cloudCoverPercent': 1.0,
#     'solarIrradiance': {'altitudeDegrees': 18.3,
#      'wattsPerSquareMeter': 793.6}},
#    {'datetime': '2023-01-07T21:00:00+00:00',
#     'outsideAirTempF': 21.0,
#     'relativeHumidityPercent': 67.6,
#     'windSpeedMph': 6.4,
#     'cloudCoverPercent': 0.6,
#     'solarIrradiance': {'altitudeDegrees': 17.9,
#      'wattsPerSquareMeter': 785.0}},
#    {'datetime': '2023-01-07T22:00:00+00:00',
#     'outsideAirTempF': 19.8,
#     'relativeHumidityPercent': 68.5,
#     'windSpeedMph': 5.9,
#     'cloudCoverPercent': 34.0,
#     'solarIrradiance': {'altitudeDegrees': 15.0,
#      'wattsPerSquareMeter': 722.1}},
#    {'datetime': '2023-01-07T23:00:00+00:00',
#     'outsideAirTempF': 19.0,
#     'relativeHumidityPercent': 70.0,
#     'windSpeedMph': 5.6,
#     'cloudCoverPercent': 14.9,
#     'solarIrradiance': {'altitudeDegrees': 10.1,
#      'wattsPerSquareMeter': 556.7}},
#    {'datetime': '2023-01-08T00:00:00+00:00',
#     'outsideAirTempF': 18.2,
#     'relativeHumidityPercent': 72.4,
#     'windSpeedMph': 5.2,
#     'cloudCoverPercent': 6.0,
#     'solarIrradiance': {'altitudeDegrees': 3.4, 'wattsPerSquareMeter': 122.5}},
#    {'datetime': '2023-01-08T01:00:00+00:00',
#     'outsideAirTempF': 17.3,
#     'relativeHumidityPercent': 73.0,
#     'windSpeedMph': 4.6,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -4.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T02:00:00+00:00',
#     'outsideAirTempF': 17.1,
#     'relativeHumidityPercent': 72.3,
#     'windSpeedMph': 4.0,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -13.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T03:00:00+00:00',
#     'outsideAirTempF': 16.5,
#     'relativeHumidityPercent': 73.8,
#     'windSpeedMph': 3.6,
#     'cloudCoverPercent': 9.3,
#     'solarIrradiance': {'altitudeDegrees': -23.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T04:00:00+00:00',
#     'outsideAirTempF': 14.9,
#     'relativeHumidityPercent': 75.4,
#     'windSpeedMph': 3.4,
#     'cloudCoverPercent': 9.3,
#     'solarIrradiance': {'altitudeDegrees': -33.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T05:00:00+00:00',
#     'outsideAirTempF': 12.7,
#     'relativeHumidityPercent': 77.8,
#     'windSpeedMph': 3.3,
#     'cloudCoverPercent': 3.6,
#     'solarIrradiance': {'altitudeDegrees': -42.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T06:00:00+00:00',
#     'outsideAirTempF': 14.8,
#     'relativeHumidityPercent': 76.4,
#     'windSpeedMph': 2.7,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -51.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T07:00:00+00:00',
#     'outsideAirTempF': 15.4,
#     'relativeHumidityPercent': 75.2,
#     'windSpeedMph': 2.5,
#     'cloudCoverPercent': 4.4,
#     'solarIrradiance': {'altitudeDegrees': -58.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T08:00:00+00:00',
#     'outsideAirTempF': 15.0,
#     'relativeHumidityPercent': 76.5,
#     'windSpeedMph': 2.6,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -62.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T09:00:00+00:00',
#     'outsideAirTempF': 13.9,
#     'relativeHumidityPercent': 78.1,
#     'windSpeedMph': 2.8,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -61.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T10:00:00+00:00',
#     'outsideAirTempF': 11.5,
#     'relativeHumidityPercent': 83.2,
#     'windSpeedMph': 3.6,
#     'cloudCoverPercent': 7.0,
#     'solarIrradiance': {'altitudeDegrees': -56.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T11:00:00+00:00',
#     'outsideAirTempF': 12.6,
#     'relativeHumidityPercent': 81.7,
#     'windSpeedMph': 3.5,
#     'cloudCoverPercent': 21.4,
#     'solarIrradiance': {'altitudeDegrees': -48.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T12:00:00+00:00',
#     'outsideAirTempF': 12.5,
#     'relativeHumidityPercent': 82.6,
#     'windSpeedMph': 4.0,
#     'cloudCoverPercent': 47.3,
#     'solarIrradiance': {'altitudeDegrees': -39.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T13:00:00+00:00',
#     'outsideAirTempF': 12.8,
#     'relativeHumidityPercent': 82.9,
#     'windSpeedMph': 4.2,
#     'cloudCoverPercent': 14.1,
#     'solarIrradiance': {'altitudeDegrees': -29.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T14:00:00+00:00',
#     'outsideAirTempF': 12.0,
#     'relativeHumidityPercent': 85.1,
#     'windSpeedMph': 4.4,
#     'cloudCoverPercent': 1.0,
#     'solarIrradiance': {'altitudeDegrees': -19.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T15:00:00+00:00',
#     'outsideAirTempF': 15.0,
#     'relativeHumidityPercent': 81.1,
#     'windSpeedMph': 4.5,
#     'cloudCoverPercent': 0.6,
#     'solarIrradiance': {'altitudeDegrees': -10.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T16:00:00+00:00',
#     'outsideAirTempF': 16.1,
#     'relativeHumidityPercent': 77.3,
#     'windSpeedMph': 4.7,
#     'cloudCoverPercent': 8.6,
#     'solarIrradiance': {'altitudeDegrees': -1.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-01-08T17:00:00+00:00',
#     'outsideAirTempF': 18.4,
#     'relativeHumidityPercent': 73.6,
#     'windSpeedMph': 5.0,
#     'cloudCoverPercent': 31.3,
#     'solarIrradiance': {'altitudeDegrees': 6.1, 'wattsPerSquareMeter': 331.7}},
#    {'datetime': '2023-01-08T18:00:00+00:00',
#     'outsideAirTempF': 19.7,
#     'relativeHumidityPercent': 72.1,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 30.4,
#     'solarIrradiance': {'altitudeDegrees': 12.2,
#      'wattsPerSquareMeter': 638.6}},
#    {'datetime': '2023-01-08T19:00:00+00:00',
#     'outsideAirTempF': 20.5,
#     'relativeHumidityPercent': 71.0,
#     'windSpeedMph': 5.7,
#     'cloudCoverPercent': 36.2,
#     'solarIrradiance': {'altitudeDegrees': 16.4,
#      'wattsPerSquareMeter': 755.4}},
#    {'datetime': '2023-01-08T20:00:00+00:00',
#     'outsideAirTempF': 21.3,
#     'relativeHumidityPercent': 70.6,
#     'windSpeedMph': 5.7,
#     'cloudCoverPercent': 62.6,
#     'solarIrradiance': {'altitudeDegrees': 18.5,
#      'wattsPerSquareMeter': 795.9}},
#    {'datetime': '2023-01-08T21:00:00+00:00',
#     'outsideAirTempF': 21.8,
#     'relativeHumidityPercent': 70.9,
#     'windSpeedMph': 4.4,
#     'cloudCoverPercent': 92.4,
#     'solarIrradiance': {'altitudeDegrees': 18.0,
#      'wattsPerSquareMeter': 787.8}},
#    {'datetime': '2023-01-08T22:00:00+00:00',
#     'outsideAirTempF': 21.7,
#     'relativeHumidityPercent': 72.7,
#     'windSpeedMph': 3.8,
#     'cloudCoverPercent': 98.6,
#     'solarIrradiance': {'altitudeDegrees': 15.2,
#      'wattsPerSquareMeter': 726.0}},
#    {'datetime': '2023-01-08T23:00:00+00:00',
#     'outsideAirTempF': 21.8,
#     'relativeHumidityPercent': 73.2,
#     'windSpeedMph': 3.5,
#     'cloudCoverPercent': 96.8,
#     'solarIrradiance': {'altitudeDegrees': 10.2,
#      'wattsPerSquareMeter': 563.7}},
#    {'datetime': '2023-01-09T00:00:00+00:00',
#     'outsideAirTempF': 21.9,
#     'relativeHumidityPercent': 74.4,
#     'windSpeedMph': 3.8,
#     'cloudCoverPercent': 96.8,
# ...
#    {'datetime': '2023-02-09T06:00:00+00:00',
#     'outsideAirTempF': 23.3,
#     'relativeHumidityPercent': 74.8,
#     'windSpeedMph': 8.8,
#     'cloudCoverPercent': 0.6,
#     'solarIrradiance': {'altitudeDegrees': -44.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T07:00:00+00:00',
#     'outsideAirTempF': 21.6,
#     'relativeHumidityPercent': 74.2,
#     'windSpeedMph': 7.3,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -51.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T08:00:00+00:00',
#     'outsideAirTempF': 19.2,
#     'relativeHumidityPercent': 75.9,
#     'windSpeedMph': 6.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -55.0, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T09:00:00+00:00',
#     'outsideAirTempF': 17.7,
#     'relativeHumidityPercent': 77.0,
#     'windSpeedMph': 6.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -54.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T10:00:00+00:00',
#     'outsideAirTempF': 15.6,
#     'relativeHumidityPercent': 78.0,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': -50.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T11:00:00+00:00',
#     'outsideAirTempF': 14.4,
#     'relativeHumidityPercent': 78.6,
#     'windSpeedMph': 5.8,
#     'cloudCoverPercent': 87.0,
#     'solarIrradiance': {'altitudeDegrees': -43.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T12:00:00+00:00',
#     'outsideAirTempF': 13.4,
#     'relativeHumidityPercent': 78.7,
#     'windSpeedMph': 6.1,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -34.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T13:00:00+00:00',
#     'outsideAirTempF': 12.9,
#     'relativeHumidityPercent': 79.2,
#     'windSpeedMph': 6.1,
#     'cloudCoverPercent': 0.2,
#     'solarIrradiance': {'altitudeDegrees': -25.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T14:00:00+00:00',
#     'outsideAirTempF': 12.4,
#     'relativeHumidityPercent': 78.7,
#     'windSpeedMph': 6.2,
#     'cloudCoverPercent': 11.9,
#     'solarIrradiance': {'altitudeDegrees': -15.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T15:00:00+00:00',
#     'outsideAirTempF': 12.5,
#     'relativeHumidityPercent': 76.4,
#     'windSpeedMph': 6.2,
#     'cloudCoverPercent': 24.9,
#     'solarIrradiance': {'altitudeDegrees': -5.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-09T16:00:00+00:00',
#     'outsideAirTempF': 14.9,
#     'relativeHumidityPercent': 72.5,
#     'windSpeedMph': 6.5,
#     'cloudCoverPercent': 99.0,
#     'solarIrradiance': {'altitudeDegrees': 3.6, 'wattsPerSquareMeter': 120.8}},
#    {'datetime': '2023-02-09T17:00:00+00:00',
#     'outsideAirTempF': 18.0,
#     'relativeHumidityPercent': 66.8,
#     'windSpeedMph': 6.9,
#     'cloudCoverPercent': 98.3,
#     'solarIrradiance': {'altitudeDegrees': 11.6,
#      'wattsPerSquareMeter': 597.1}},
#    {'datetime': '2023-02-09T18:00:00+00:00',
#     'outsideAirTempF': 21.2,
#     'relativeHumidityPercent': 63.2,
#     'windSpeedMph': 6.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 18.4,
#      'wattsPerSquareMeter': 773.3}},
#    {'datetime': '2023-02-09T19:00:00+00:00',
#     'outsideAirTempF': 24.2,
#     'relativeHumidityPercent': 59.9,
#     'windSpeedMph': 6.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 23.4,
#      'wattsPerSquareMeter': 848.0}},
#    {'datetime': '2023-02-09T20:00:00+00:00',
#     'outsideAirTempF': 25.8,
#     'relativeHumidityPercent': 60.1,
#     'windSpeedMph': 6.9,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 25.9,
#      'wattsPerSquareMeter': 877.0}},
#    {'datetime': '2023-02-09T21:00:00+00:00',
#     'outsideAirTempF': 28.1,
#     'relativeHumidityPercent': 58.6,
#     'windSpeedMph': 6.7,
#     'cloudCoverPercent': 94.0,
#     'solarIrradiance': {'altitudeDegrees': 25.8,
#      'wattsPerSquareMeter': 875.6}},
#    {'datetime': '2023-02-09T22:00:00+00:00',
#     'outsideAirTempF': 28.9,
#     'relativeHumidityPercent': 58.4,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 92.4,
#     'solarIrradiance': {'altitudeDegrees': 23.0,
#      'wattsPerSquareMeter': 843.2}},
#    {'datetime': '2023-02-09T23:00:00+00:00',
#     'outsideAirTempF': 28.6,
#     'relativeHumidityPercent': 58.2,
#     'windSpeedMph': 5.6,
#     'cloudCoverPercent': 17.3,
#     'solarIrradiance': {'altitudeDegrees': 17.8,
#      'wattsPerSquareMeter': 762.1}},
#    {'datetime': '2023-02-10T00:00:00+00:00',
#     'outsideAirTempF': 27.2,
#     'relativeHumidityPercent': 60.4,
#     'windSpeedMph': 6.2,
#     'cloudCoverPercent': 36.2,
#     'solarIrradiance': {'altitudeDegrees': 10.9,
#      'wattsPerSquareMeter': 567.9}},
#    {'datetime': '2023-02-10T01:00:00+00:00',
#     'outsideAirTempF': 25.5,
#     'relativeHumidityPercent': 64.1,
#     'windSpeedMph': 6.0,
#     'cloudCoverPercent': 29.2,
#     'solarIrradiance': {'altitudeDegrees': 2.8, 'wattsPerSquareMeter': 60.9}},
#    {'datetime': '2023-02-10T02:00:00+00:00',
#     'outsideAirTempF': 25.3,
#     'relativeHumidityPercent': 66.0,
#     'windSpeedMph': 6.0,
#     'cloudCoverPercent': 49.1,
#     'solarIrradiance': {'altitudeDegrees': -6.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T03:00:00+00:00',
#     'outsideAirTempF': 25.6,
#     'relativeHumidityPercent': 68.1,
#     'windSpeedMph': 5.9,
#     'cloudCoverPercent': 20.6,
#     'solarIrradiance': {'altitudeDegrees': -16.3, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T04:00:00+00:00',
#     'outsideAirTempF': 25.1,
#     'relativeHumidityPercent': 70.9,
#     'windSpeedMph': 5.9,
#     'cloudCoverPercent': 11.1,
#     'solarIrradiance': {'altitudeDegrees': -26.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T05:00:00+00:00',
#     'outsideAirTempF': 23.9,
#     'relativeHumidityPercent': 72.7,
#     'windSpeedMph': 5.7,
#     'cloudCoverPercent': 10.0,
#     'solarIrradiance': {'altitudeDegrees': -35.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T06:00:00+00:00',
#     'outsideAirTempF': 24.1,
#     'relativeHumidityPercent': 73.9,
#     'windSpeedMph': 5.6,
#     'cloudCoverPercent': 22.5,
#     'solarIrradiance': {'altitudeDegrees': -44.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T07:00:00+00:00',
#     'outsideAirTempF': 23.4,
#     'relativeHumidityPercent': 76.0,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 4.9,
#     'solarIrradiance': {'altitudeDegrees': -50.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T08:00:00+00:00',
#     'outsideAirTempF': 23.6,
#     'relativeHumidityPercent': 77.1,
#     'windSpeedMph': 5.3,
#     'cloudCoverPercent': 15.5,
#     'solarIrradiance': {'altitudeDegrees': -54.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T09:00:00+00:00',
#     'outsideAirTempF': 22.7,
#     'relativeHumidityPercent': 78.9,
#     'windSpeedMph': 5.4,
#     'cloudCoverPercent': 20.2,
#     'solarIrradiance': {'altitudeDegrees': -54.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T10:00:00+00:00',
#     'outsideAirTempF': 21.6,
#     'relativeHumidityPercent': 80.0,
#     'windSpeedMph': 5.9,
#     'cloudCoverPercent': 50.3,
#     'solarIrradiance': {'altitudeDegrees': -50.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T11:00:00+00:00',
#     'outsideAirTempF': 21.4,
#     'relativeHumidityPercent': 80.9,
#     'windSpeedMph': 6.0,
#     'cloudCoverPercent': 77.4,
#     'solarIrradiance': {'altitudeDegrees': -43.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T12:00:00+00:00',
#     'outsideAirTempF': 21.6,
#     'relativeHumidityPercent': 80.0,
#     'windSpeedMph': 5.6,
#     'cloudCoverPercent': 58.1,
#     'solarIrradiance': {'altitudeDegrees': -34.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T13:00:00+00:00',
#     'outsideAirTempF': 21.8,
#     'relativeHumidityPercent': 80.4,
#     'windSpeedMph': 6.1,
#     'cloudCoverPercent': 78.4,
#     'solarIrradiance': {'altitudeDegrees': -24.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T14:00:00+00:00',
#     'outsideAirTempF': 22.8,
#     'relativeHumidityPercent': 79.9,
#     'windSpeedMph': 6.3,
#     'cloudCoverPercent': 42.9,
#     'solarIrradiance': {'altitudeDegrees': -15.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T15:00:00+00:00',
#     'outsideAirTempF': 23.4,
#     'relativeHumidityPercent': 78.7,
#     'windSpeedMph': 7.0,
#     'cloudCoverPercent': 18.4,
#     'solarIrradiance': {'altitudeDegrees': -5.5, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-10T16:00:00+00:00',
#     'outsideAirTempF': 26.4,
#     'relativeHumidityPercent': 73.3,
#     'windSpeedMph': 8.9,
#     'cloudCoverPercent': 18.9,
#     'solarIrradiance': {'altitudeDegrees': 3.8, 'wattsPerSquareMeter': 139.4}},
#    {'datetime': '2023-02-10T17:00:00+00:00',
#     'outsideAirTempF': 33.7,
#     'relativeHumidityPercent': 62.6,
#     'windSpeedMph': 11.7,
#     'cloudCoverPercent': 29.5,
#     'solarIrradiance': {'altitudeDegrees': 11.9,
#      'wattsPerSquareMeter': 605.5}},
#    {'datetime': '2023-02-10T18:00:00+00:00',
#     'outsideAirTempF': 37.2,
#     'relativeHumidityPercent': 57.7,
#     'windSpeedMph': 11.8,
#     'cloudCoverPercent': 72.8,
#     'solarIrradiance': {'altitudeDegrees': 18.7,
#      'wattsPerSquareMeter': 777.4}},
#    {'datetime': '2023-02-10T19:00:00+00:00',
#     'outsideAirTempF': 39.5,
#     'relativeHumidityPercent': 56.4,
#     'windSpeedMph': 11.0,
#     'cloudCoverPercent': 94.2,
#     'solarIrradiance': {'altitudeDegrees': 23.7,
#      'wattsPerSquareMeter': 850.6}},
#    {'datetime': '2023-02-10T20:00:00+00:00',
#     'outsideAirTempF': 40.5,
#     'relativeHumidityPercent': 52.6,
#     'windSpeedMph': 11.9,
#     'cloudCoverPercent': 82.0,
#     'solarIrradiance': {'altitudeDegrees': 26.3,
#      'wattsPerSquareMeter': 879.1}},
#    {'datetime': '2023-02-10T21:00:00+00:00',
#     'outsideAirTempF': 40.8,
#     'relativeHumidityPercent': 54.4,
#     'windSpeedMph': 11.8,
#     'cloudCoverPercent': 98.4,
#     'solarIrradiance': {'altitudeDegrees': 26.1,
#      'wattsPerSquareMeter': 877.8}},
#    {'datetime': '2023-02-10T22:00:00+00:00',
#     'outsideAirTempF': 40.9,
#     'relativeHumidityPercent': 56.5,
#     'windSpeedMph': 9.6,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 23.3,
#      'wattsPerSquareMeter': 845.9}},
#    {'datetime': '2023-02-10T23:00:00+00:00',
#     'outsideAirTempF': 41.1,
#     'relativeHumidityPercent': 55.5,
#     'windSpeedMph': 7.2,
#     'cloudCoverPercent': 100.0,
#     'solarIrradiance': {'altitudeDegrees': 18.1,
#      'wattsPerSquareMeter': 766.5}},
#    {'datetime': '2023-02-11T00:00:00+00:00',
#     'outsideAirTempF': 39.7,
#     'relativeHumidityPercent': 54.6,
#     'windSpeedMph': 6.8,
#     'cloudCoverPercent': 20.9,
#     'solarIrradiance': {'altitudeDegrees': 11.2,
#      'wattsPerSquareMeter': 577.2}},
#    {'datetime': '2023-02-11T01:00:00+00:00',
#     'outsideAirTempF': 37.9,
#     'relativeHumidityPercent': 55.3,
#     'windSpeedMph': 7.7,
#     'cloudCoverPercent': 3.4,
#     'solarIrradiance': {'altitudeDegrees': 3.0, 'wattsPerSquareMeter': 77.4}},
#    {'datetime': '2023-02-11T02:00:00+00:00',
#     'outsideAirTempF': 36.6,
#     'relativeHumidityPercent': 55.2,
#     'windSpeedMph': 8.4,
#     'cloudCoverPercent': 10.2,
#     'solarIrradiance': {'altitudeDegrees': -6.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T03:00:00+00:00',
#     'outsideAirTempF': 36.5,
#     'relativeHumidityPercent': 54.2,
#     'windSpeedMph': 8.9,
#     'cloudCoverPercent': 16.4,
#     'solarIrradiance': {'altitudeDegrees': -16.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T04:00:00+00:00',
#     'outsideAirTempF': 36.2,
#     'relativeHumidityPercent': 54.0,
#     'windSpeedMph': 9.1,
#     'cloudCoverPercent': 39.9,
#     'solarIrradiance': {'altitudeDegrees': -25.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T05:00:00+00:00',
#     'outsideAirTempF': 34.6,
#     'relativeHumidityPercent': 55.7,
#     'windSpeedMph': 9.1,
#     'cloudCoverPercent': 54.6,
#     'solarIrradiance': {'altitudeDegrees': -35.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T06:00:00+00:00',
#     'outsideAirTempF': 33.1,
#     'relativeHumidityPercent': 56.5,
#     'windSpeedMph': 9.2,
#     'cloudCoverPercent': 61.8,
#     'solarIrradiance': {'altitudeDegrees': -43.8, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T07:00:00+00:00',
#     'outsideAirTempF': 32.0,
#     'relativeHumidityPercent': 58.6,
#     'windSpeedMph': 9.4,
#     'cloudCoverPercent': 83.2,
#     'solarIrradiance': {'altitudeDegrees': -50.6, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T08:00:00+00:00',
#     'outsideAirTempF': 30.5,
#     'relativeHumidityPercent': 60.2,
#     'windSpeedMph': 9.5,
#     'cloudCoverPercent': 81.0,
#     'solarIrradiance': {'altitudeDegrees': -54.4, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T09:00:00+00:00',
#     'outsideAirTempF': 29.3,
#     'relativeHumidityPercent': 61.1,
#     'windSpeedMph': 9.0,
#     'cloudCoverPercent': 67.7,
#     'solarIrradiance': {'altitudeDegrees': -54.1, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T10:00:00+00:00',
#     'outsideAirTempF': 26.9,
#     'relativeHumidityPercent': 65.6,
#     'windSpeedMph': 8.2,
#     'cloudCoverPercent': 0.4,
#     'solarIrradiance': {'altitudeDegrees': -49.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T11:00:00+00:00',
#     'outsideAirTempF': 25.3,
#     'relativeHumidityPercent': 67.1,
#     'windSpeedMph': 6.7,
#     'cloudCoverPercent': 0.0,
#     'solarIrradiance': {'altitudeDegrees': -42.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T12:00:00+00:00',
#     'outsideAirTempF': 23.9,
#     'relativeHumidityPercent': 68.7,
#     'windSpeedMph': 6.3,
#     'cloudCoverPercent': 0.6,
#     'solarIrradiance': {'altitudeDegrees': -34.2, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T13:00:00+00:00',
#     'outsideAirTempF': 22.3,
#     'relativeHumidityPercent': 69.8,
#     'windSpeedMph': 6.7,
#     'cloudCoverPercent': 17.0,
#     'solarIrradiance': {'altitudeDegrees': -24.7, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T14:00:00+00:00',
#     'outsideAirTempF': 21.4,
#     'relativeHumidityPercent': 69.9,
#     'windSpeedMph': 7.0,
#     'cloudCoverPercent': 59.1,
#     'solarIrradiance': {'altitudeDegrees': -14.9, 'wattsPerSquareMeter': 0.0}},
#    {'datetime': '2023-02-11T15:00:00+00:00',
#     'outsideAirTempF': 20.4,
#     'relativeHumidityPercent': 69.5,
#     'windSpeedMph': 7.4,
#     'cloudCoverPercent': 76.7,
#     'solarIrradiance': {'altitudeDegrees': -5.3, 'wattsPerSquareMeter': 0.0}},
#    ...]}}
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 11:19:15  Samples:  42290
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 71.813    CPU time: 43.017
# /   _/                      v4.6.2
#
# Program: /Users/jlfwong/code/hvac-math/scripts/weather/.venv/lib/python3.8/site-packages/ipykernel_launcher.py -f /Users/jlfwong/Library/Jupyter/runtime/kernel-b272d40e-e63c-4d21-a148-165bb30ecde6.json
#
# 71.842 <module>  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/4148602475.py:2
# |- 40.553 func_with_check  pysolar/tzinfo_check.py:54
# |     [30 frames hidden]  pysolar, inspect
# |        17.196 get_nutation  pysolar/solar.py:270
# |        `- 15.980 [self]  pysolar/solar.py
# |- 17.866 <listcomp>  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/4148602475.py:7
# |  `- 17.858 get_timezone  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/2541908534.py:1
# |     `- 17.858 get  requests/api.py:62
# |           [47 frames hidden]  requests, urllib3, ssl, <built-in>, h...
# |- 11.315 <listcomp>  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/4148602475.py:8
# |  `- 11.306 get_elevation  ../../../../../../var/folders/80/29_gz6bj01nb95w7vf2ty_rw0000gn/T/ipykernel_7054/147570816.py:3
# |     `- 11.306 get  requests/api.py:62
# |           [27 frames hidden]  requests, urllib3, ssl, <built-in>, h...
# `- 1.071 get_radiation_direct  pysolar/radiation.py:43
#       [2 frames hidden]  pysolar

# %%
results_by_postal_code.keys()
# Out:
# dict_keys(['K2A', 'V5K', 'H3H', 'R3T', 'T6G'])

# %%
import json

for postal_code, results in results_by_postal_code.items():
    with open(f'../../static/data/weather/2023-era5-{postal_code}.json', 'w') as file:
        json.dump(results, file)
